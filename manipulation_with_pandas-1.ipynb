# %%
import pandas as pd

# %%
dict_data={"Firstname":["Imma","Vini","Celsia","Stancia","Nabilatou","Elohim","Gloria","Consolas","Carine"],
           "Age":[23,22,20,23,22,18,22,23,22],
           "Mat":["23WIADA0001","23WIADA0002","23WIADA0003","23WIADA0004","23WIADA0005","23WIADA0006","23WIADA0007","23WIADA0008","23WIADA0009"]}

# %%
df=pd.DataFrame(dict_data)
df
# Out:
#    Firstname  Age          Mat
# 0       Imma   23  23WIADA0001
# 1       Vini   22  23WIADA0002
# 2     Celsia   20  23WIADA0003
# 3    Stancia   23  23WIADA0004
# 4  Nabilatou   22  23WIADA0005
# 5     Elohim   18  23WIADA0006
# 6     Gloria   22  23WIADA0007
# 7   Consolas   23  23WIADA0008
# 8     Carine   22  23WIADA0009

# %%
df.Firstname
# Out:
# 0         Imma
# 1         Vini
# 2       Celsia
# 3      Stancia
# 4    Nabilatou
# 5       Elohim
# 6       Gloria
# 7     Consolas
# 8       Carine
# Name: Firstname, dtype: object

# %%
df["Firstname"]
# Out:
# 0         Imma
# 1         Vini
# 2       Celsia
# 3      Stancia
# 4    Nabilatou
# 5       Elohim
# 6       Gloria
# 7     Consolas
# 8       Carine
# Name: Firstname, dtype: object

# %%
df[["Firstname","Mat"]]
# Out:
#    Firstname          Mat
# 0       Imma  23WIADA0001
# 1       Vini  23WIADA0002
# 2     Celsia  23WIADA0003
# 3    Stancia  23WIADA0004
# 4  Nabilatou  23WIADA0005
# 5     Elohim  23WIADA0006
# 6     Gloria  23WIADA0007
# 7   Consolas  23WIADA0008
# 8     Carine  23WIADA0009

# %%
df.loc[1]
# Out:
# Firstname           Vini
# Age                   22
# Mat          23WIADA0002
# Name: 1, dtype: object

# %%
df.loc[1,["Firstname","Age"]]
# Out:
# Firstname    Vini
# Age            22
# Name: 1, dtype: object

# %%
df.loc[1,"Mat"]
# Out:
# '23WIADA0002'

# %%
df.loc[:,"Mat"]
# Out:
# 0    23WIADA0001
# 1    23WIADA0002
# 2    23WIADA0003
# 3    23WIADA0004
# 4    23WIADA0005
# 5    23WIADA0006
# 6    23WIADA0007
# 7    23WIADA0008
# 8    23WIADA0009
# Name: Mat, dtype: object

# %%
df.loc[:9,"Mat"]
# Out:
# 0    23WIADA0001
# 1    23WIADA0002
# 2    23WIADA0003
# 3    23WIADA0004
# 4    23WIADA0005
# 5    23WIADA0006
# 6    23WIADA0007
# 7    23WIADA0008
# 8    23WIADA0009
# Name: Mat, dtype: object

# %%
df.loc[3:,["Firstname","Mat"]]
# Out:
#    Firstname          Mat
# 3    Stancia  23WIADA0004
# 4  Nabilatou  23WIADA0005
# 5     Elohim  23WIADA0006
# 6     Gloria  23WIADA0007
# 7   Consolas  23WIADA0008
# 8     Carine  23WIADA0009

# %%
df.loc[3:6,["Firstname","Mat"]]
# Out:
#    Firstname          Mat
# 3    Stancia  23WIADA0004
# 4  Nabilatou  23WIADA0005
# 5     Elohim  23WIADA0006
# 6     Gloria  23WIADA0007

# %%
df.iloc[1]
# Out:
# Firstname           Vini
# Age                   22
# Mat          23WIADA0002
# Name: 1, dtype: object

# %%
df.iloc[1,0]
# Out:
# 'Vini'

# %%
df
# Out:
#    Firstname  Age          Mat
# 0       Imma   23  23WIADA0001
# 1       Vini   22  23WIADA0002
# 2     Celsia   20  23WIADA0003
# 3    Stancia   23  23WIADA0004
# 4  Nabilatou   22  23WIADA0005
# 5     Elohim   18  23WIADA0006
# 6     Gloria   22  23WIADA0007
# 7   Consolas   23  23WIADA0008
# 8     Carine   22  23WIADA0009

# %%
df.iloc[3:7,[0,2]]
# Out:
#    Firstname          Mat
# 3    Stancia  23WIADA0004
# 4  Nabilatou  23WIADA0005
# 5     Elohim  23WIADA0006
# 6     Gloria  23WIADA0007

# %%
df.iloc[3:7,:2]
# Out:
#    Firstname  Age
# 3    Stancia   23
# 4  Nabilatou   22
# 5     Elohim   18
# 6     Gloria   22

# %%
df.sort_values("Firstname")
# Out:
#    Firstname  Age          Mat
# 8     Carine   22  23WIADA0009
# 2     Celsia   20  23WIADA0003
# 7   Consolas   23  23WIADA0008
# 5     Elohim   18  23WIADA0006
# 6     Gloria   22  23WIADA0007
# 0       Imma   23  23WIADA0001
# 4  Nabilatou   22  23WIADA0005
# 3    Stancia   23  23WIADA0004
# 1       Vini   22  23WIADA0002

# %%
df.sort_values("Firstname",ascending=False)
# Out:
#    Firstname  Age          Mat
# 1       Vini   22  23WIADA0002
# 3    Stancia   23  23WIADA0004
# 4  Nabilatou   22  23WIADA0005
# 0       Imma   23  23WIADA0001
# 6     Gloria   22  23WIADA0007
# 5     Elohim   18  23WIADA0006
# 7   Consolas   23  23WIADA0008
# 2     Celsia   20  23WIADA0003
# 8     Carine   22  23WIADA0009

# %%
df.sort_values(["Firstname","Mat"],ascending=False)
# Out:
#    Firstname  Age          Mat
# 1       Vini   22  23WIADA0002
# 3    Stancia   23  23WIADA0004
# 4  Nabilatou   22  23WIADA0005
# 0       Imma   23  23WIADA0001
# 6     Gloria   22  23WIADA0007
# 5     Elohim   18  23WIADA0006
# 7   Consolas   23  23WIADA0008
# 2     Celsia   20  23WIADA0003
# 8     Carine   22  23WIADA0009

# %%
df.iloc[0,0]="Immaculée Conception"

# %%
df.iloc[2,1]=21

# %%
df
# Out:
#               Firstname  Age          Mat
# 0  Immaculée Conception   23  23WIADA0001
# 1                  Vini   22  23WIADA0002
# 2                Celsia   21  23WIADA0003
# 3               Stancia   23  23WIADA0004
# 4             Nabilatou   22  23WIADA0005
# 5                Elohim   18  23WIADA0006
# 6                Gloria   22  23WIADA0007
# 7              Consolas   23  23WIADA0008
# 8                Carine   22  23WIADA0009

# %%
df.drop(2,inplace=True)

# %%
df.reset_index(inplace=True)

# %%
df.columns
# Out:
# Index(['index', 'Firstname', 'Age', 'Mat'], dtype='object')

# %%
df.drop("index",axis=1,inplace=True)

# %%
df.set_index("Mat",inplace=True)

# %%
df.columns
# Out:
# Index(['Firstname', 'Age'], dtype='object')

# %%
df.index.name
# Out:
# 'Mat'

# %% [markdown]
# ## Fonction lambda

# %%
f=lambda x:x**2

# %%
f(3)
# Out:
# 9

# %%
g=lambda x:x+"_WIADA"

# %%
g("Stella")
# Out:
# 'Stella_WIADA'

# %%
df
# Out:
#                         Firstname  Age
# Mat
# 23WIADA0001  Immaculée Conception   23
# 23WIADA0002                  Vini   22
# 23WIADA0004               Stancia   23
# 23WIADA0005             Nabilatou   22
# 23WIADA0006                Elohim   18
# 23WIADA0007                Gloria   22
# 23WIADA0008              Consolas   23
# 23WIADA0009                Carine   22

# %%
df["Firstname"]=df["Firstname"].apply(g)

# %%
df
# Out:
#                               Firstname  Age
# Mat
# 23WIADA0001  Immaculée Conception_WIADA   23
# 23WIADA0002                  Vini_WIADA   22
# 23WIADA0004               Stancia_WIADA   23
# 23WIADA0005             Nabilatou_WIADA   22
# 23WIADA0006                Elohim_WIADA   18
# 23WIADA0007                Gloria_WIADA   22
# 23WIADA0008              Consolas_WIADA   23
# 23WIADA0009                Carine_WIADA   22

# %%
df["Status"]=["M","M","F","M","C","C","M","Mae"]

# %%
df
# Out:
#                               Firstname  Age Status
# Mat
# 23WIADA0001  Immaculée Conception_WIADA   23      M
# 23WIADA0002                  Vini_WIADA   22      M
# 23WIADA0004               Stancia_WIADA   23      F
# 23WIADA0005             Nabilatou_WIADA   22      M
# 23WIADA0006                Elohim_WIADA   18      C
# 23WIADA0007                Gloria_WIADA   22      C
# 23WIADA0008              Consolas_WIADA   23      M
# 23WIADA0009                Carine_WIADA   22    Mae

# %%
df.insert(loc=2,column="ville",value=["Cot","Cal","Oui","Cal","Cot","Porto","Oui","Cot"])

# %%
df
# Out:
#                               Firstname  Age  ville Status
# Mat
# 23WIADA0001  Immaculée Conception_WIADA   23    Cot      M
# 23WIADA0002                  Vini_WIADA   22    Cal      M
# 23WIADA0004               Stancia_WIADA   23    Oui      F
# 23WIADA0005             Nabilatou_WIADA   22    Cal      M
# 23WIADA0006                Elohim_WIADA   18    Cot      C
# 23WIADA0007                Gloria_WIADA   22  Porto      C
# 23WIADA0008              Consolas_WIADA   23    Oui      M
# 23WIADA0009                Carine_WIADA   22    Cot    Mae

# %%
nouv={"Firstname":"Eunice","Age":33,"ville":"Cal","Status":"C","Mat":["23WIADA0010"]}

# %%
df.append({"Firstname":"Eunice","Age":33,"ville":"Cal","Status":"C"},ignore_index=True)
# Out:
# /tmp/ipykernel_9471/1694120693.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append({"Firstname":"Eunice","Age":33,"ville":"Cal","Status":"C"},ignore_index=True)
#                     Firstname  Age  ville Status
# 0  Immaculée Conception_WIADA   23    Cot      M
# 1                  Vini_WIADA   22    Cal      M
# 2               Stancia_WIADA   23    Oui      F
# 3             Nabilatou_WIADA   22    Cal      M
# 4                Elohim_WIADA   18    Cot      C
# 5                Gloria_WIADA   22  Porto      C
# 6              Consolas_WIADA   23    Oui      M
# 7                Carine_WIADA   22    Cot    Mae
# 8                      Eunice   33    Cal      C

# %%
nouv=pd.DataFrame(nouv)

# %%
nouv.set_index("Mat",inplace=True)

# %%
nouv
# Out:
#             Firstname  Age ville Status
# Mat
# 23WIADA0010    Eunice   33   Cal      C

# %%
df=pd.concat([df,nouv])

# %%
df
# Out:
#                               Firstname  Age  ville Status
# Mat
# 23WIADA0001  Immaculée Conception_WIADA   23    Cot      M
# 23WIADA0002                  Vini_WIADA   22    Cal      M
# 23WIADA0004               Stancia_WIADA   23    Oui      F
# 23WIADA0005             Nabilatou_WIADA   22    Cal      M
# 23WIADA0006                Elohim_WIADA   18    Cot      C
# 23WIADA0007                Gloria_WIADA   22  Porto      C
# 23WIADA0008              Consolas_WIADA   23    Oui      M
# 23WIADA0009                Carine_WIADA   22    Cot    Mae
# 23WIADA0010                      Eunice   33    Cal      C

# %%
df[df["Age"]<22]
# Out:
#                 Firstname  Age ville Status
# Mat
# 23WIADA0006  Elohim_WIADA   18   Cot      C

# %%
df[(df["Age"]>22) & (df["ville"]=="Cal")]
# Out:
#             Firstname  Age ville Status
# Mat
# 23WIADA0010    Eunice   33   Cal      C

# %%
df[(df["Age"]>22) | (df["ville"]=="Cal")]
# Out:
#                               Firstname  Age ville Status
# Mat
# 23WIADA0001  Immaculée Conception_WIADA   23   Cot      M
# 23WIADA0002                  Vini_WIADA   22   Cal      M
# 23WIADA0004               Stancia_WIADA   23   Oui      F
# 23WIADA0005             Nabilatou_WIADA   22   Cal      M
# 23WIADA0008              Consolas_WIADA   23   Oui      M
# 23WIADA0010                      Eunice   33   Cal      C

# %%
df["ville"].value_counts()
# Out:
# Cot      3
# Cal      3
# Oui      2
# Porto    1
# Name: ville, dtype: int64

# %%
df.groupby("Status").value_counts()
# Out:
# Status  Firstname                   Age  ville
# C       Elohim_WIADA                18   Cot      1
#         Eunice                      33   Cal      1
#         Gloria_WIADA                22   Porto    1
# F       Stancia_WIADA               23   Oui      1
# M       Consolas_WIADA              23   Oui      1
#         Immaculée Conception_WIADA  23   Cot      1
#         Nabilatou_WIADA             22   Cal      1
#         Vini_WIADA                  22   Cal      1
# Mae     Carine_WIADA                22   Cot      1
# dtype: int64

# %%
df.groupby("Status",group_keys=True).apply(lambda x:x)
# Out:
#                                      Firstname  Age  ville Status
# Status Mat
# C      23WIADA0006                Elohim_WIADA   18    Cot      C
#        23WIADA0007                Gloria_WIADA   22  Porto      C
#        23WIADA0010                      Eunice   33    Cal      C
# F      23WIADA0004               Stancia_WIADA   23    Oui      F
# M      23WIADA0001  Immaculée Conception_WIADA   23    Cot      M
#        23WIADA0002                  Vini_WIADA   22    Cal      M
#        23WIADA0005             Nabilatou_WIADA   22    Cal      M
#        23WIADA0008              Consolas_WIADA   23    Oui      M
# Mae    23WIADA0009                Carine_WIADA   22    Cot    Mae

# %%
new=df.groupby("Status",group_keys=True).apply(lambda x:x)[["Age","Firstname"]]

# %%
new.groupby("Age",group_keys=True).apply(lambda x:x)
# Out:
#                         Age                   Firstname
# Age Status Mat
# 18  C      23WIADA0006   18                Elohim_WIADA
# 22  C      23WIADA0007   22                Gloria_WIADA
#     M      23WIADA0002   22                  Vini_WIADA
#            23WIADA0005   22             Nabilatou_WIADA
#     Mae    23WIADA0009   22                Carine_WIADA
# 23  F      23WIADA0004   23               Stancia_WIADA
#     M      23WIADA0001   23  Immaculée Conception_WIADA
#            23WIADA0008   23              Consolas_WIADA
# 33  C      23WIADA0010   33                      Eunice

# %%
df=pd.read_csv("Documents/data-2.csv",sep=",")

# %%
df.shape
# Out:
# (541909, 8)

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
#df.to_excel("test_data.xlsx")

# %%
df.isna().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
df.shape
# Out:
# (541909, 8)

# %%
1454*100/df.shape[0]
# Out:
# 0.2683107311375157

# %%
135080*100/df.shape[0]
# Out:
# 24.926694334288598

# %%
1454*100/df.shape[0]
# Out:
# 0.2683107311375157

# %%
135080*100/df.shape[0]
# Out:
# 24.926694334288598

# %%
df.isna().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
df.dropna()
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
df.dropna(axis="columns")
# Out:
#        InvoiceNo StockCode  Quantity      InvoiceDate  UnitPrice  \
# 0         536365    85123A         6   12/1/2010 8:26       2.55
# 1         536365     71053         6   12/1/2010 8:26       3.39
# 2         536365    84406B         8   12/1/2010 8:26       2.75
# 3         536365    84029G         6   12/1/2010 8:26       3.39
# 4         536365    84029E         6   12/1/2010 8:26       3.39
# ...          ...       ...       ...              ...        ...
# 541904    581587     22613        12  12/9/2011 12:50       0.85
# 541905    581587     22899         6  12/9/2011 12:50       2.10
# 541906    581587     23254         4  12/9/2011 12:50       4.15
# 541907    581587     23255         4  12/9/2011 12:50       4.15
# 541908    581587     22138         3  12/9/2011 12:50       4.95
#
#                Country
# 0       United Kingdom
# 1       United Kingdom
# 2       United Kingdom
# 3       United Kingdom
# 4       United Kingdom
# ...                ...
# ...

# %%
new=df.drop("CustomerID",axis=1)

# %%
new
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice         Country
# ...

# %%
new.dropna(inplace=True)

# %%
new.isna().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# Country        0
# dtype: int64

# %%
new.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 541904    False
# 541905    False
# 541906    False
# 541907    False
# 541908    False
# Length: 540455, dtype: bool

# %%
new[new.duplicated()]
# Out:
#        InvoiceNo StockCode                        Description  Quantity  \
# 517       536409     21866        UNION JACK FLAG LUGGAGE TAG         1
# 527       536409     22866      HAND WARMER SCOTTY DOG DESIGN         1
# 537       536409     22900    SET 2 TEA TOWELS I LOVE LONDON          1
# 539       536409     22111       SCOTTIE DOG HOT WATER BOTTLE         1
# 555       536412     22327  ROUND SNACK BOXES SET OF 4 SKULLS         1
# ...          ...       ...                                ...       ...
# 541675    581538     22068        BLACK PIRATE TREASURE CHEST         1
# 541689    581538     23318     BOX OF 6 MINI VINTAGE CRACKERS         1
# 541692    581538     22992             REVOLVER WOODEN RULER          1
# 541699    581538     22694                       WICKER STAR          1
# 541701    581538     23343       JUMBO BAG VINTAGE CHRISTMAS          1
#
#             InvoiceDate  UnitPrice         Country
# 517     12/1/2010 11:45       1.25  United Kingdom
# ...

# %%
new.shape
# Out:
# (540455, 7)

# %%
new.drop_duplicates(inplace=True)

# %%
new
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice         Country
# ...

# %%
new.shape
# Out:
# (535187, 7)

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
df.groupby(["Country","InvoiceNo"])[["Quantity","UnitPrice"]].agg(min).sort_values("UnitPrice")
# Out:
#                           Quantity  UnitPrice
# Country        InvoiceNo
# United Kingdom A563186           1  -11062.06
#                A563187           1  -11062.06
#                572477          -15       0.00
#                540560          -14       0.00
#                540564        -2600       0.00
# ...                            ...        ...
#                C537651          -1   13541.33
#                C540118          -1   16453.71
#                C540117          -1   16888.02
#                C580605          -1   17836.46
#                C556445          -1   38970.00
#
# [25900 rows x 2 columns]

# %%
(df["UnitPrice"]<0).sum()
# Out:
# 2

# %%
df[df["UnitPrice"]<0].UnitPrice
# Out:
# 299983   -11062.06
# 299984   -11062.06
# Name: UnitPrice, dtype: float64

# %%
df.replace([x for x in df[df["UnitPrice"]<0].UnitPrice],0,inplace=True)

# %%
(df["UnitPrice"]<0).sum()
# Out:
# 0

# %%
df.groupby(["Country","InvoiceNo"])[["Quantity","UnitPrice"]].agg(min).sort_values("UnitPrice")
# Out:
#                           Quantity  UnitPrice
# Country        InvoiceNo
# United Kingdom 572477          -15       0.00
#                540558          -29       0.00
#                540560          -14       0.00
#                540564        -2600       0.00
#                540637           -5       0.00
# ...                            ...        ...
#                C537651          -1   13541.33
#                C540118          -1   16453.71
#                C540117          -1   16888.02
#                C580605          -1   17836.46
#                C556445          -1   38970.00
#
# [25900 rows x 2 columns]
